# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
dataset = pd.read_csv(r"C:\Users\Dell\Downloads\emp_sal.csv")
dataset
# Out:
#                Position  Level   Salary
# 0  Jr Software Engineer      1    45000
# 1  Sr Software Engineer      2    50000
# 2             Team Lead      3    60000
# 3               Manager      4    80000
# 4            Sr manager      5   110000
# 5        Region Manager      6   150000
# 6                   AVP      7   200000
# 7                    VP      8   300000
# 8                   CTO      9   500000
# 9                   CEO     10  1000000

# %%
# Independent Variable & Dependent Variable
x = dataset.iloc[:,1:2].values #Experience
y = dataset.iloc[:, 2].values  # Salary

# %%
# Train-Test-Split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling (Mandatory for KNN)
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()

# %%
x_train_scaled = sc_x.fit_transform(x_train)
x_test_scaled = sc_x.transform(x_test)

# %%
from sklearn.metrics import r2_score

for k in range(1,9):
    model = KNeighborsRegressor(n_neighbors = k,weights = 'distance')
    model.fit(x_train_scaled,y_train)
    y_pred = model.predict(x_test_scaled)
    print(k,r2_score(y_test, y_pred))
# Out:
# 1 0.5857438016528926
# 2 0.7673037190082648
# 3 0.9627995867768596
# 4 0.9977021065880574
# 5 0.9924519385681471
# 6 0.9720785369937124
# 7 0.9460314204800594
# 8 0.8899770105329503

# %%
# KNN Regression Model
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors = 4, weights = 'distance', metric = 'minkowski', p = 2)

# %%
regressor.fit(x_train_scaled,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4, weights='distance')

# %%
# Prediction for test set
y_pred_test = regressor.predict(x_test_scaled)

# %%
# Predicton for 6.5 years experience
x_65_scaled = sc_x.transform([[6.5]])
y_65 = regressor.predict(x_65_scaled)
y_65
# Out:
# array([182500.])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred_test)
mse
# Out:
# 111218041.13802332

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(10545.996450692714)

# %%
# Visualization (Training set)
x_grid = np.arange(min(x_train),max(x_train),0.1).reshape(-1,1)

plt.scatter(x_train,y_train, color = 'red')
plt.plot(x_grid,regressor.predict(sc_x.transform(x_grid)), color = 'blue')
plt.title('Salary vs Experience (KNN Regression)')
plt.xlabel('Experience')
plt.ylabel('')
