# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\Dell\Downloads\logit classification.csv")
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
# Divide Variable Into Independent Variable & Dependent Variable
x = dataset.iloc[:, [2,3]].values
y = dataset.iloc[:, -1].values

# %%
# Split the datat into test trai split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
# Standardization 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
# Logistic Model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# Prediction
y_pred = classifier.predict(x_test)

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[57  1]
#  [ 5 17]]

# %%
# Accuracy of model
from sklearn.metrics import accuracy_score
ac = accuracy_score(y_test,y_pred)
print(ac)
# Out:
# 0.925

# %%
# Classification report
from sklearn.metrics import classification_report
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95        58
#            1       0.94      0.77      0.85        22
#
#     accuracy                           0.93        80
#    macro avg       0.93      0.88      0.90        80
# weighted avg       0.93      0.93      0.92        80

# %% [markdown]
# # Future Prediction

# %%
# Future dataset
dataset1 = pd.read_csv(r"C:\Users\Dell\Downloads\15. Logistic regression with future prediction\15. Logistic regression with future prediction\Future prediction1.csv")

# %%
dataset1
# Out:
#     User ID  Gender  Age  EstimatedSalary
# 0  15724611    Male   45            60000
# 1  15725621  Female   79            64000
# 2  15725622    Male   23            78000
# 3  15720611  Female   34            45000
# 4  15588044    Male   29            76000
# 5  15746039  Female   70            89000
# 6  15704887    Male   86           120000
# 7  15746009  Female   46            23000
# 8  15876009    Male   32            70000
# 9  15886009  Female  100            90000

# %%
# Copy of dataset
d2 = dataset1.copy()

# %%
dataset1 = dataset1.iloc[:,[2,3]].values

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
M = sc.fit_transform(dataset1)

# %%
y_pred1 = pd.DataFrame()

# %%
d2['y_pred1'] = classifier.predict(M)

# %%
d2.to_csv('final.csv')

# %%
d2
# Out:
#     User ID  Gender  Age  EstimatedSalary  y_pred1
# 0  15724611    Male   45            60000        0
# 1  15725621  Female   79            64000        1
# 2  15725622    Male   23            78000        0
# 3  15720611  Female   34            45000        0
# 4  15588044    Male   29            76000        0
# 5  15746039  Female   70            89000        1
# 6  15704887    Male   86           120000        1
# 7  15746009  Female   46            23000        0
# 8  15876009    Male   32            70000        0
# 9  15886009  Female  100            90000        1

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dell'
